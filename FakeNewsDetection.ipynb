# %%
import shutil

# %%
zipfile = '/content/drive/MyDrive/Machine learning project/FakeNewsDetection/test.csv.zip'
unzip_to = '/content/drive/MyDrive/Machine learning project/FakeNewsDetection'
shutil.unpack_archive(zipfile, unzip_to)
